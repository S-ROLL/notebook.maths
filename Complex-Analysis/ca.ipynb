# %% [markdown]
# # Giải tích hàm biến phức
# ## Sơ đồ nội dung

# %%
import graphviz
from graphviz import Graph

dot = graphviz.Graph('G', filename='hello.gv')

dot.attr('node', shape='box', style='rounded', fontname='sans-serif', fontcolor='gray20')
dot.graph_attr['rankdir'] = 'LR'

dot.node('HBP',label='HAM BIEN PHUC')
dot.node('C2', label='Ham bien phuc')
dot.node('C3', label='Ham chinh hinh')
dot.node('C4', label='Tich phan ham chinh hinh')
dot.node('C5', label='Chuoi Taylor & LT thang du')
dot.node('dhp', label='dao ham phuc')
dot.node('dkcr', label='dk cauchy-rieman')
dot.node('hch', label='ham chinh hinh')
dot.node('ynhh', label='y nghia hinh hoc')
dot.node('axptt', label='Anh xa phan tuyen tinh')
dot.node('hbsp', label='ham bien so phuc')
dot.node('ghlt', label='gh & lien tuc')
dot.node('chchsc', label='chuoi ham - cac ham so cap')
dot.node('tphp', label='tich phan ham phuc')
dot.node('dlcc', label='dly cauchy')
dot.node('ltcc', label='ly thuyet cauchy')
dot.node('tplcc', label='tich phan loai cauchy')
dot.node('dlcbhch', label='cac dly co ban ham chinh hinh')
dot.node('hdh', label='ham dieu hoa')
dot.node('kttl', label='Khai trien Taylor')
dot.node('dlxddn', label='Dly xac dinh duy nhat')
dot.node('ktlr', label='Khai trien Laurentz')

dot.edge('HBP','C2')
dot.edge('HBP','C3')
dot.edge('HBP','C4')
dot.edge('HBP','C5')
dot.edge('C2','hbsp')
dot.edge('C2','ghlt')
dot.edge('C2','chchsc')
dot.edge('C3','dhp')
dot.edge('C3','dkcr')
dot.edge('C3','hch')
dot.edge('C3','ynhh')
dot.edge('C3','axptt')
dot.edge('C4','tphp')
dot.edge('C4','dlcc')
dot.edge('C4','ltcc')
dot.edge('C4','tplcc')
dot.edge('C4','dlcbhch')
dot.edge('C4','hdh')
dot.edge('C5','kttl')
dot.edge('C5','dlxddn')
dot.edge('C5','ktlr')

dot.attr('node', fontname='sans-serif', fontcolor='gray20', color="white")

dot.edge('hbsp','tim anh cua...qua anh xa...')
dot.edge('dkcr','xet tinh kha vi phuc...')
dot.edge('hch','xet tinh chinh hinh cua ham...')
dot.edge('axptt','tim axptt cua...')
dot.edge('axptt','tim anh cua mien...qua anh xa...')
dot.edge('tphp','tinh tp')
dot.edge('dlcc','tinh tp...voi gramma la chu tuyen tron \n vay quanh diem a')
dot.edge('ltcc','tinh tp...voi gramma la chu tuyen tron \n ko di qua...')
dot.edge('tplcc','tinh tp...voi gramma la chu tuyen tron \n ko di qua...va...')
dot.edge('ghlt','xet tinh lien tuc lien tuc deu \n cua ham...tren mien...')

with dot.subgraph(name='cluster_0') as c:
    c.attr(style='rounded', color='black')
    c.node_attr.update(style='filled')
    c.node('tim anh cua...qua anh xa...')
    c.node('xet tinh kha vi phuc...')
    c.node('xet tinh chinh hinh cua ham...')
    c.node('tim axptt cua...')
    c.node('tim anh cua mien...qua anh xa...')
    c.node('tinh tp')
    c.node('tinh tp...voi gramma la chu tuyen tron \n vay quanh diem a')
    c.node('tinh tp...voi gramma la chu tuyen tron \n ko di qua...')
    c.node('tinh tp...voi gramma la chu tuyen tron \n ko di qua...va...')
    c.node('xet tinh lien tuc lien tuc deu \n cua ham...tren mien...')
    c.attr(label='DANG BT', fontname='sans-serif', fontsize='20')

dot
