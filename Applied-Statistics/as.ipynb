# %% [markdown]
# # Applied Statistics

# %% [markdown]
# ## Source

# %% [markdown]
# [gg photos](https://photos.google.com/u/0/share/AF1QipPR0PFFFPI2DKhB05EDSK4tRVTW4eXhaNWDnGxExucFF0Ls8lKCFiYRFd3u2AQ9GA?key=SFpCa1FqQWltTmV6VlJnVEZUME9CZkpJcDdZWUdR)

# %% [markdown]
# [SPSS Equation List (GPT4)](https://chat.openai.com/share/5ee9ce13-a38b-4025-95e9-5a1a8bd977c7)

# %% [markdown]
# # Contents

# %% [markdown]
# | STT | TEST CONTENTS | ENG |
# | ----------- | ----------- | ----------- |
# | 1 | Kiểm định tỉ lệ tổng thể (new) | [Nonparametic Test/Legacy Dialogs/Binomial Test](https://youtu.be/cC4jitq5hGM?si=z4OaGhB8aiiz1qJQ) |
# | 2 | Kiểm định giá trị trung bình tổng thể (new) | [One-sample T Test](https://youtu.be/B2HkeiYYFig?si=tJOb0T9o697a1D5a) |
# | 3 | Kiểm định tính độc lập <br/> So sánh tỉ lệ 2 tổng thể | [Crosstab/Chi-square](https://youtu.be/82nGWJCv6zA?si=C5EOnkKxBdsnLd1k) |
# | 4 | So sánh 2 giá trị trung bình theo cặp | [Paired-sample T Test](https://youtu.be/GZFB22JFJsk?si=jp3lKYhhIEXXPRyq) |
# | 5 | Phân tích phương sai 1 nhân tố | [Compare means/One-way ANOVA](https://youtu.be/zV7OCPdIVus?si=NLDbyWeVSD04OecS) |
# | 6 | Hypothesis Tests | |
# | 7 | | [Independent sample t test](https://youtu.be/ZNlGdkowUd4?si=Hrg59Fq1FAjfmX5g) |

# %% [markdown]
# # Binomial Test

# %% [markdown]
# ![A4746D4E-D9A4-4B41-901A-C8D20BFC00C0_4_5005_c.jpeg](attachment:A4746D4E-D9A4-4B41-901A-C8D20BFC00C0_4_5005_c.jpeg)

# %% [markdown]
# ### Thông tin

# %% [markdown]
# ### Nguồn gốc

# %% [markdown]
# # One-sample t-test

# %% [markdown]
# ![F5CD28E1-B0F2-4852-8251-CA9D9652E86A_4_5005_c.jpeg](attachment:F5CD28E1-B0F2-4852-8251-CA9D9652E86A_4_5005_c.jpeg) ![C46B0AAC-1A2E-4099-87A9-8EB1401A5569_4_5005_c.jpeg](attachment:C46B0AAC-1A2E-4099-87A9-8EB1401A5569_4_5005_c.jpeg)

# %% [markdown]
# ### Thông tin

# %% [markdown]
# ### Nguồn gốc

# %% [markdown]
# # Independent-samples t-test

# %% [markdown]
# ![1D81A3BF-C81C-48C5-AC86-E23D7D15ABF4.png](attachment:1D81A3BF-C81C-48C5-AC86-E23D7D15ABF4.png)

# %% [markdown]
# ### Thông tin

# %% [markdown]
# ### Nguồn gốc

# %% [markdown]
# $$
# \begin{split}
# \text{Std. Error Mean } &= \frac{\text{Std. Deviation}}{\sqrt{N}} \\
# s^2 &= \frac{(n-1)s_1^2 + (m-1)s_2^2}{n+m-2} \\
# t &= \frac{\overline{x}_1 -\overline{x}_2}{\sqrt{\frac{s^2}{n} + \frac{s^2}{m}}} \\
# df &= m + n -2
# \end{split}
# $$

# %% [markdown]
# # Paired-samples t-test

# %% [markdown]
# ![5D2B4F90-68E7-4AFE-A0A6-28D68183AF03_4_5005_c.jpeg](attachment:5D2B4F90-68E7-4AFE-A0A6-28D68183AF03_4_5005_c.jpeg) ![6A1B4443-EB8E-4941-997D-EA4F21C8F4E9_4_5005_c.jpeg](attachment:6A1B4443-EB8E-4941-997D-EA4F21C8F4E9_4_5005_c.jpeg)

# %% [markdown]
# ### Thông tin

# %% [markdown]
# <p style="text-align: center;">Bảng 2.1</p>

# %% [markdown]
# - **Mean**
# - **N**
# - **Std. Deviation**
# - **Std Error Mean**

# %% [markdown]
# <p style="text-align: center;">Bảng 2.2</p>

# %% [markdown]
# - **95% Confidence Interval of Difference**
#   - **Lower**
#   - **Upper**
# - **t**
# - **df**
# - **Sig (2-talled)**

# %% [markdown]
# ### Nguồn gốc

# %% [markdown]
# $$
# \begin{split}
# \text{std. Error Mean } &= \frac{\text{std. Deviation}}{\sqrt{N}} \\
# \text{Mean } &= \overline{x}_1 - \overline{x}_2 \\
# t &= \frac{\text{Mean}\sqrt{N}}{\text{std. Deviation}} \\
# df &= N -1 \\
# \end{split}
# $$

# %% [markdown]
# # One-way ANOVA

# %% [markdown]
# ![72EF5FC0-B3E9-4A50-AA6D-751B82E3711B.png](attachment:72EF5FC0-B3E9-4A50-AA6D-751B82E3711B.png)

# %% [markdown]
# ### Thông tin

# %% [markdown]
# <p style="text-align: center;">Bảng 3.1</p>

# %% [markdown]
# - **N**
# - **Mean**
# - **Std. Deviation**
# - **Std. Error**
# - **95% Confidence Interval for Mean**
#   - **Lower Bound**
#   - **Upper Bound**
# - **Minimum**
# - **Maximum**

# %% [markdown]
# <p style="text-align: center;">Bảng 3.2</p>

# %% [markdown]
# - **Leneve Statistics**
# - **df 1**
# - **df 2**
# - **Sig**

# %% [markdown]
# <p style="text-align: center;">Bảng 3.3</p>

# %% [markdown]
# - **Between Groups**
# - **Within Groups**
# - **Sum of Squares**
# - **df**
# - **Mean Square**
# - **F**
# - **Sig**

# %% [markdown]
# # Crosstabs/Chi-square

# %% [markdown]
# ![AA6E2E89-3467-4337-B828-A671B320D6D9.png](attachment:AA6E2E89-3467-4337-B828-A671B320D6D9.png)

# %% [markdown]
# ### Thông tin

# %% [markdown]
# <p style="text-align: center;">Bảng 3.1</p>

# %% [markdown]
# <p style="text-align: center;">Bảng 3.2</p>

# %% [markdown]
# <p style="text-align: center;">Bảng 3.3</p>

# %% [markdown]
# ### Nguồn gốc

# %% [markdown]
# $$
# \text{Expected Count } = \frac{\text{Count}\times 100}{N}
# $$

# %% [markdown]
# ---

# %% [markdown]
# # [Statistics for B&E](https://drive.google.com/file/d/1kgX-EG2cZ60YqFv5lA5kxp_JA94YZLNO/view?usp=sharing)

# %% [markdown]
# ## Checklist

# %% [markdown]
# | STT | TITLE | CHECKLIST |
# | ----------- | ----------- | ----------- |
# | 1 | Data and Statistics | <input type="checkbox"> |
# | 2 | Descriptive Statistics: Tabular and Graphical Displays | <input type="checkbox"> |
# | 3 | Descriptive Statistics: Numerical Measures | <input type="checkbox"> |
# | 4 | Introduction to Probability | <input type="checkbox"> |
# | 5 | Discrete Probability Distributions | <input type="checkbox"> |
# | 6 | Continuous Probability Distributions | <input type="checkbox"> |
# | 7 | Sampling and Sampling Distributions | <input type="checkbox"> |
# | 8 | Interval Estimation | <input type="checkbox"> |
# | 9 | Hypothesis Tests | <input type="checkbox"> |

# %% [markdown]
# ## Contents

# %% [markdown]
# - **Data and Statistics**
#     - Applications in Business and Economics
#     - Data
#     - Data Sources
#     - Descriptive Statistics
#     - Statistical Inference
#     - Analytics
#     - Big Data and Data Mining
#     - Computers and Statistical Analysis
#     - Ethical Guidelines for Statistical Practice
# - **Descriptive Statistics: Tabular and Graphical Displays**
#     - Summarizing Data for a Categorical Variable
#     - Summarizing Data for a Quantitative Variable
#     - Summarizing Data for Two Variables Using Tables
#     - Summarizing Data for Two Variables Using Graphical Displays
#     - Data Visualization: Best Practices in Creating Effective Graphical Displays
# - **Descriptive Statistics: Numerical Measures**
#     - Measures of Location
#     - Measures of Variability
#     - Measures of Distribution Shape, Relative Location, and Detecting Outliers
#     - Five-Number Summaries and Box Plots
#     - Measures of Association Between Two Variables
#     - Data Dashboards: Adding Numerical Measures to Improve Effectiveness
# - **Introduction to Probability**
#     - Random Experiments, Counting Rules, and Assigning Probabilities
#     - Events and Their Probabilities
#     - Some Basic Relationships of Probability
#     - Conditional Probability
#     - Bayes’ Theorem
# - **Discrete Probability Distributions**
#     - Random Variables
#     - Developing Discrete Probability Distributions
#     - Expected Value and Variance
#     - Bivariate Distributions, Covariance, and Financial Portfolios
#     - Binomial Probability Distribution
#     - Poisson Probability Distribution
#     - Hypergeometric Probability Distribution
# - **Continuous Probability Distributions**
#     - Uniform Probability Distribution
#     - Normal Probability Distribution
#     - Normal Approximation of Binomial Probabilities
#     - Exponential Probability Distribution
# - **Sampling and Sampling Distributions**
#     - The Electronics Associates Sampling Problem
#     - Selecting a Sample
#     - Point Estimation
#     - Introduction to Sampling Distributions
#     - Sampling Distribution of $\overline{\rm x}$
#     - Sampling Distribution of $\overline{\rm p}$
#     - Properties of Point Estimators
#     - Other Sampling Methods
# - **Interval Estimation**
#     - Population Mean: $\sigma$ Known
#     - Population Mean: $\sigma$ Unknown
#     - Determining the Sample Size
#     - Population Proportion
# - **Hypothesis Tests**
#     - Developing Null and Alternative Hypotheses
#     - Type $I$ and Type $II$ Errors
#     - Population Mean: $\sigma$ Known
#     - Population Mean: $\sigma$ Unknown
#     - Population Proportion
#     - Hypothesis Testing and Decision Making
#     - Calculating the Probability of Type $II$ Errors
#     - Determining the Sample Size for a Hypothesis Test About a Population Mean

# %% [markdown]
# ## Graph content

# %%
import graphviz
from graphviz import Graph

dot = graphviz.Graph('G', filename='hello.gv')

dot.attr('node', shape='box', style='rounded', fontname='sans-serif', fontcolor='gray20')
dot.graph_attr['rankdir'] = 'LR'

dot.node('stt',label='Statistics')
dot.node('pbblt',label='Probability')
dot.node('dsbt',label='Distributions')
dot.node('dscr',label='Discrete')
dot.node('ctno',label='Continuous')
dot.node('spl',label='Sampling')
dot.node('iesm',label='Interval estimate')
dot.node('hpt',label='Hypothesis test')
dot.node('bcrt',label='Base characteristic')
dot.node('bnm',label='Binomial')
dot.node('ps',label='Poisson')
dot.node('hpgmt',label='Hyper geometric')
dot.node('eptvl',label='Expected value \n Variance \n Standard deviation \n Mode \n Med')
dot.node('rdv',label='Random variables')
dot.node('bvr',label='Bivariate')
dot.node('tp',label='Types')
dot.node('cvra',label='Covariance \n Correlation')
dot.node('lncb',label='Linear combination')
dot.node('unf',label='uniform')
dot.node('nm',label='normal')
dot.node('epnt',label='exponential')

dot.edge('stt','pbblt')
dot.edge('pbblt','dsbt')
dot.edge('pbblt','iesm')
dot.edge('pbblt','hpt')
dot.edge('pbblt','spl')
dot.edge('dscr','bnm')
dot.edge('dscr','ps')
dot.edge('dscr','hpgmt')
dot.edge('bcrt','eptvl')
dot.edge('tp','dscr')
dot.edge('tp','ctno')
dot.edge('tp','bvr')
dot.edge('dsbt','bcrt')
dot.edge('dsbt','rdv')
dot.edge('dsbt','tp')
dot.edge('bvr','cvra')
dot.edge('bvr','lncb')
dot.edge('ctno','unf')
dot.edge('ctno','nm')
dot.edge('ctno','epnt')

dot.attr('edge', style='dotted', fontname='sans-serif')

dot.edge('nm','bnm')
dot.edge('epnt','ps')

dot
