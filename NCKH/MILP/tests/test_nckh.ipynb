# %% [markdown]
# ## Testing - MILP

# %% [markdown]
# $$
# \begin{split}
#     (P) \quad z_p= & 5.5x_1 + 2.1x_2 + 3x_3 \quad \longrightarrow Max \\
#     & \left\{\begin{split}
#     & -x_1 + x_2 + x_3 \leq 2 \\
#     & 8x_1 + 2x_2 + x_3\leq 17 \\
#     & 9x_1 + x_2 + 6x_3 \leq 20 \\
#     &x_i \geq 0 , \: i=\overline{\rm 1, \ldots ,3} \\
#     \end{split}\right. \\
# \end{split}
# $$

# %%
from scipy.optimize import linprog

c = [-5.5, -2.1, -3]
A = [[-1, 1, 1], [8, 2, 1], [9, 1, 6]]
b = [2, 17, 20]

x0_bounds = (0, None)
x1_bounds = (0, None)
x2_bounds = (0, None)

res = linprog(c, A_ub=A, b_ub=b, bounds=[x0_bounds, x1_bounds, x2_bounds])

print('Gia tri toi uu =', res.fun)
print('Bien toi uu =', res.x)
# Out:
# Gia tri toi uu = -15.463333333333335
# Bien toi uu = [1.38333333 2.55       0.83333333]

# %%
import schemdraw
from schemdraw import flow

with schemdraw.Drawing() as d:
    d.config(fontsize=12, unit=1)
    d += flow.Terminal().label('$P_0$')
    d += flow.Arrow().down()
    d1 += flow.Decision(W='a').label('aaa')
    flow.Arrow().down().at(d1.W)
    d += flow.Box().label('b')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/chibangnguyen/Documents/GitHub/Bancie.github.io/notebook.maths/NCKH/tests/test_nckh.ipynb Cell 4 line 8
#       <a href='vscode-notebook-cell:/Users/chibangnguyen/Documents/GitHub/Bancie.github.io/notebook.maths/NCKH/tests/test_nckh.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a> d += flow.Terminal().label('$P_0$')
#       <a href='vscode-notebook-cell:/Users/chibangnguyen/Documents/GitHub/Bancie.github.io/notebook.maths/NCKH/tests/test_nckh.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a> d += flow.Arrow().down()
# ----> <a href='vscode-notebook-cell:/Users/chibangnguyen/Documents/GitHub/Bancie.github.io/notebook.maths/NCKH/tests/test_nckh.ipynb#W6sZmlsZQ%3D%3D?line=7'>8</a> d1 += flow.Decision(W='a').label('aaa')
#       <a href='vscode-notebook-cell:/Users/chibangnguyen/Documents/GitHub/Bancie.github.io/notebook.maths/NCKH/tests/test_nckh.ipynb#W6sZmlsZQ%3D%3D?line=8'>9</a> flow.Arrow().down().at(d1.W)
#      <a href='vscode-notebook-cell:/Users/chibangnguyen/Documents/GitHub/Bancie.github.io/notebook.maths/NCKH/tests/test_nckh.ipynb#W6sZmlsZQ%3D%3D?line=9'>10</a> d += flow.Box().label('b')
#
# NameError: name 'd1' is not defined

# %% [markdown]
# $$
# \begin{split}
#     (P_1^1) \quad z_p= & 5.5x_1 + 2.1x_2 + 3x_3 \quad \longrightarrow Max \\
#     & \left\{\begin{split}
#     & -x_1 + x_2 + x_3 \leq 2 \\
#     & 8x_1 + 2x_2 + x_3\leq 17 \\
#     & 9x_1 + x_2 + 6x_3 \leq 20 \\
#     & x_1 \leq 1 \\
#     &x_i \geq 0 , \: i=\overline{\rm 1, \ldots ,3} \\
#     \end{split}\right. \\
# \end{split}
# $$

# %%
from scipy.optimize import linprog

c = [-5.5, -2.1, -3]
A = [[-1, 1, 1], [8, 2, 1], [9, 1, 6], [1, 0, 0]]
b = [2, 17, 20, 1]

x0_bounds = (0, None)
x1_bounds = (0, None)
x2_bounds = (0, None)

res = linprog(c, A_ub=A, b_ub=b, bounds=[x0_bounds, x1_bounds, x2_bounds])

print('Gia tri toi uu =', res.fun)
print('Bien toi uu =', res.x)
# Out:
# Gia tri toi uu = -13.24
# Bien toi uu = [1.  1.4 1.6]

# %% [markdown]
# $$
# \begin{split}
#     (P_1^2) \quad z_p= & 5.5x_1 + 2.1x_2 + 3x_3 \quad \longrightarrow Max \\
#     & \left\{\begin{split}
#     & -x_1 + x_2 + x_3 \leq 2 \\
#     & 8x_1 + 2x_2 + x_3\leq 17 \\
#     & 9x_1 + x_2 + 6x_3 \leq 20 \\
#     & x_1 \geq 2 \\
#     &x_i \geq 0 , \: i=\overline{\rm 1, \ldots ,3} \\
#     \end{split}\right. \\
# \end{split}
# $$

# %%
from scipy.optimize import linprog

c = [-5.5, -2.1, -3]
A = [[-1, 1, 1], [8, 2, 1], [9, 1, 6], [-1, 0, 0]]
b = [2, 17, 20, -2]

x0_bounds = (0, None)
x1_bounds = (0, None)
x2_bounds = (0, None)

res = linprog(c, A_ub=A, b_ub=b, bounds=[x0_bounds, x1_bounds, x2_bounds])

print('Gia tri toi uu =', res.fun)
print('Bien toi uu =', res.x)
# Out:
# Gia tri toi uu = -12.581818181818182
# Bien toi uu = [2.         0.36363636 0.27272727]

# %% [markdown]
# $$
# \begin{split}
#     (P_2^1) \quad z_p= & 5.5x_1 + 2.1x_2 + 3x_3 \quad \longrightarrow Max \\
#     & \left\{\begin{split}
#     & -x_1 + x_2 + x_3 \leq 2 \\
#     & 8x_1 + 2x_2 + x_3\leq 17 \\
#     & 9x_1 + x_2 + 6x_3 \leq 20 \\
#     & x_2 \leq 2 \\
#     &x_i \geq 0 , \: i=\overline{\rm 1, \ldots ,3} \\
#     \end{split}\right. \\
# \end{split}
# $$

# %%
from scipy.optimize import linprog

c = [-5.5, -2.1, -3]
A = [[-1, 1, 1], [8, 2, 1], [9, 1, 6], [0, 1, 0]]
b = [2, 17, 20, 2]

x0_bounds = (0, None)
x1_bounds = (0, None)
x2_bounds = (0, None)

res = linprog(c, A_ub=A, b_ub=b, bounds=[x0_bounds, x1_bounds, x2_bounds])

print('Gia tri toi uu =', res.fun)
print('Bien toi uu =', res.x)
# Out:
# Gia tri toi uu = -14.738461538461536
# Bien toi uu = [1.53846154 2.         0.69230769]

# %% [markdown]
# $$
# \begin{split}
#     (P_2^2) \quad z_p= & 5.5x_1 + 2.1x_2 + 3x_3 \quad \longrightarrow Max \\
#     & \left\{\begin{split}
#     & -x_1 + x_2 + x_3 \leq 2 \\
#     & 8x_1 + 2x_2 + x_3\leq 17 \\
#     & 9x_1 + x_2 + 6x_3 \leq 20 \\
#     & x_2 \geq 3 \\
#     &x_i \geq 0 , \: i=\overline{\rm 1, \ldots ,3} \\
#     \end{split}\right. \\
# \end{split}
# $$

# %%
from scipy.optimize import linprog

c = [-5.5, -2.1, -3]
A = [[-1, 1, 1], [8, 2, 1], [9, 1, 6], [0, -1, 0]]
b = [2, 17, 20, -3]

x0_bounds = (0, None)
x1_bounds = (0, None)
x2_bounds = (0, None)

res = linprog(c, A_ub=A, b_ub=b, bounds=[x0_bounds, x1_bounds, x2_bounds])

print('Gia tri toi uu =', res.fun)
print('Bien toi uu =', res.x)
# Out:
# Gia tri toi uu = -14.633333333333333
# Bien toi uu = [1.33333333 3.         0.33333333]

# %% [markdown]
# $$
# \begin{split}
#     (P_3^1) \quad z_p= & 5.5x_1 + 2.1x_2 + 3x_3 \quad \longrightarrow Max \\
#     & \left\{\begin{split}
#     & -x_1 + x_2 + x_3 \leq 2 \\
#     & 8x_1 + 2x_2 + x_3\leq 17 \\
#     & 9x_1 + x_2 + 6x_3 \leq 20 \\
#     & x_3 \leq 0 \\
#     &x_i \geq 0 , \: i=\overline{\rm 1, \ldots ,3} \\
#     \end{split}\right. \\
# \end{split}
# $$

# %%
from scipy.optimize import linprog

c = [-5.5, -2.1, -3]
A = [[-1, 1, 1], [8, 2, 1], [9, 1, 6], [0, 0, 1]]
b = [2, 17, 20, 0]

x0_bounds = (0, None)
x1_bounds = (0, None)
x2_bounds = (0, None)

res = linprog(c, A_ub=A, b_ub=b, bounds=[x0_bounds, x1_bounds, x2_bounds])

print('Gia tri toi uu =', res.fun)
print('Bien toi uu =', res.x)
# Out:
# Gia tri toi uu = -14.08
# Bien toi uu = [ 1.3  3.3 -0. ]

# %% [markdown]
# $$
# \begin{split}
#     (P_3^2) \quad z_p= & 5.5x_1 + 2.1x_2 + 3x_3 \quad \longrightarrow Max \\
#     & \left\{\begin{split}
#     & -x_1 + x_2 + x_3 \leq 2 \\
#     & 8x_1 + 2x_2 + x_3\leq 17 \\
#     & 9x_1 + x_2 + 6x_3 \leq 20 \\
#     & x_3 \geq 1 \\
#     &x_i \geq 0 , \: i=\overline{\rm 1, \ldots ,3} \\
#     \end{split}\right. \\
# \end{split}
# $$

# %%
from scipy.optimize import linprog

c = [-5.5, -2.1, -3]
A = [[-1, 1, 1], [8, 2, 1], [9, 1, 6], [0, 0, -1]]
b = [2, 17, 20, -1]

x0_bounds = (0, None)
x1_bounds = (0, None)
x2_bounds = (0, None)

res = linprog(c, A_ub=A, b_ub=b, bounds=[x0_bounds, x1_bounds, x2_bounds])

print('Gia tri toi uu =', res.fun)
print('Bien toi uu =', res.x)
# Out:
# Gia tri toi uu = -14.98
# Bien toi uu = [1.3 2.3 1. ]

# %% [markdown]
# | Bai toan | gia tri toi uu | $x_1$ | $x_2$ | $x_3$ |
# | ----------- | ----------- | ----------- | ----------- | ----------- |
# | $P_1^1$ | 13.24 | 1 | 1.4 | 1.6 |
# | $P_1^2$ | 12.58 | 2 | .36 | .27 |
# | $P_2^1$ | 14.73 | 1.53 | 2 | .69 |
# | $P_2^2$ | 14.63 | 1.33 | 3 | .33 |
# | $P_3^1$ | 14.08 | 1.3 | 3.3 | 0 |
# | $P_3^2$ | 14.98 | 1.3 | 2.3 | 1 |

# %%
import graphviz
from graphviz import Graph

dot = graphviz.Graph('G', filename='hello.gv')

dot.attr('node', shape='box', style='rounded', fontname='sans-serif', fontcolor='gray20')
dot.graph_attr['rankdir'] = 'LR'

dot.node('p0',label='P0')
dot.node('p0x1',label='x1=1.4')
dot.node('p0x2',label='x2=2.5')
dot.node('p0x3',label='x3=.8')

dot.node('p11', label='P11')
dot.node('p11x2', label='x2=1.4')
dot.node('p11x3', label='x3=1.6')

dot.node('p12', label='P12')

dot.edge('p0','p0x1')
dot.edge('p0','p0x2')
dot.edge('p0','p0x3')
dot.edge('p0x1','p11')
dot.edge('p0x1','p12')
dot.edge('p11','p11x2')
dot.edge('p11', 'p11x3')

dot

# %% [markdown]
# $$
# \begin{split}
#     (P_4^1) \quad z_p= & 5.5x_1 + 2.1x_2 + 3x_3 \quad \longrightarrow Max \\
#     & \left\{\begin{split}
#     & -x_1 + x_2 + x_3 \leq 2 \\
#     & 8x_1 + 2x_2 + x_3\leq 17 \\
#     & 9x_1 + x_2 + 6x_3 \leq 20 \\
#     & x_1 \leq 1 \\
#     & x_2 \leq 1 \\
#     &x_i \geq 0 , \: i=\overline{\rm 1, \ldots ,3} \\
#     \end{split}\right. \\
# \end{split}
# $$

# %%
from scipy.optimize import linprog

c = [-5.5, -2.1, -3]
A = [[-1, 1, 1], [8, 2, 1], [9, 1, 6], [1, 0, 0], [0, 1, 0]]
b = [2, 17, 20, 1, 1]

x0_bounds = (0, None)
x1_bounds = (0, None)
x2_bounds = (0, None)

res = linprog(c, A_ub=A, b_ub=b, bounds=[x0_bounds, x1_bounds, x2_bounds])

print('Gia tri toi uu =', res.fun)
print('Bien toi uu =', res.x)
# Out:
# Gia tri toi uu = -12.6
# Bien toi uu = [1.         1.         1.66666667]

# %% [markdown]
# $$
# \begin{split}
#     (P_{16}^1) \quad z_p= & 5.5x_1 + 2.1x_2 + 3x_3 \quad \longrightarrow Max \\
#     & \left\{\begin{split}
#     & -x_1 + x_2 + x_3 \leq 2 \\
#     & 8x_1 + 2x_2 + x_3\leq 17 \\
#     & 9x_1 + x_2 + 6x_3 \leq 20 \\
#     & x_1 \leq 1 \\
#     & x_2 \leq 1 \\
#     & x_3 \leq 1 \\
#     &x_i \geq 0 , \: i=\overline{\rm 1, \ldots ,3} \\
#     \end{split}\right. \\
# \end{split}
# $$

# %%
from scipy.optimize import linprog

c = [-5.5, -2.1, -3]
A = [[-1, 1, 1], [8, 2, 1], [9, 1, 6], [1, 0, 0], [0, 1, 0], [0, 0, 1]]
b = [2, 17, 20, 1, 1, 1]

x0_bounds = (0, None)
x1_bounds = (0, None)
x2_bounds = (0, None)

res = linprog(c, A_ub=A, b_ub=b, bounds=[x0_bounds, x1_bounds, x2_bounds])

print('Gia tri toi uu =', res.fun)
print('Bien toi uu =', res.x)
# Out:
# Gia tri toi uu = -10.6
# Bien toi uu = [1. 1. 1.]
